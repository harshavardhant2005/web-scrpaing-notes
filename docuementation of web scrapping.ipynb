# %% [markdown]
# # This file is to docuement web scarping using selenium
# here instead of install chrome driver manager manually
# we use webdriver_manager which is to provide chromedriver manager for us without we install by manually
# we service inorder to make chrome driver manger install using .install method

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.google.com/")

# %% [markdown]
# ### we have an problem browser open and closes automatically here is the fix for it
# we use something called options to disable the automatic behaviour of browser preventing it from automatic closer

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
chrome_options = Options()
chrome_options.add_experimental_option("detach",True)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),options=chrome_options)
driver.get("https://www.google.com/")
#driver.quit()

# %% [markdown]
# ### in this section we are going to see how to access a data from  webpage
# once we get the url from driver we use find_element method here we use x path to access information from the page
#
# in this example i am fetch data of property in housing.com website

# %%
#driver code to start selenium 
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
chrome_options = Options()
chrome_options.add_experimental_option("detach",True)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),options=chrome_options)
driver.get("https://housing.com/in/buy/chennai/chennai")

# access info start here 
title = driver.find_element("xpath", "/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[2]/div/article/div[1]/div[2]/div[1]/div[1]/div[1]/a/h2")
print(title.text)

price = driver.find_element("xpath", "/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[1]/div/article/div[1]/div[2]/div[1]/div[3]/div/div[1]/div[1]")
print(price.text)

area = driver.find_element("xpath", "/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[1]/div/article/div[1]/div[2]/div[1]/div[3]/div/div[2]/div[1]")
print(area.text)

status = driver.find_element("xpath", "/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[1]/div/article/div[1]/div[2]/div[1]/div[3]/div/div[3]/div[1]")
print(status.text)


driver.quit()

# %% [markdown]
# ### in the next section i am going to access multiple property data from the web ( fetching details from whole web )
#
# identify the pattern in the each x path make use of loop and fetch all data
# use try and catch i case data is not proper

# %%
#driver code to start selenium 
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
chrome_options = Options()
chrome_options.add_experimental_option("detach",True)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),options=chrome_options)
driver.get("https://housing.com/in/buy/chennai/house-chennai")

# for index must start with div number it present and 
for i in range(1,5):
    title = driver.find_element("xpath",f"/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[{i}]/div/article/div[1]/div[2]/div[1]/div[1]/div[1]/a/h2")
    print(title.text)

    price = driver.find_element("xpath",f"/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[{i}]/div/article/div[1]/div[2]/div[1]/div[3]/div/div[1]/div[1]")
    print(price.text)

    area = driver.find_element("xpath",f"/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[{i}]/div/article/div[1]/div[2]/div[1]/div[3]/div/div[2]/div[1]")
    print(area.text)

    status = driver.find_element("xpath",f"/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[{i}]/div/article/div[1]/div[2]/div[1]/div[3]/div/div[3]/div[1]")
    print(status.text)


driver.quit()

# %% [markdown]
# ### in this section we are going to access data from multiple pages
# example we should be able to fetch data from single page and able to move to the next page

# %%
#driver code to start selenium 
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
chrome_options = Options()
chrome_options.add_experimental_option("detach",True)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),options=chrome_options)
driver.get("https://housing.com/in/buy/chennai/house-chennai?page=2")

# for each page data record
for page in range(1,3):
    for i in range(1,5):
        title = driver.find_element("xpath",f"/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[{i}]/div/article/div[1]/div[2]/div[1]/div[1]/div[1]/a/h2")
        print(title.text)

        price = driver.find_element("xpath",f"/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[{i}]/div/article/div[1]/div[2]/div[1]/div[3]/div/div[1]/div[1]")
        print(price.text)

        area = driver.find_element("xpath",f"/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[{i}]/div/article/div[1]/div[2]/div[1]/div[3]/div/div[2]/div[1]")
        print(area.text)

        status = driver.find_element("xpath",f"/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[{i}]/div/article/div[1]/div[2]/div[1]/div[3]/div/div[3]/div[1]")
        print(status.text)
        print("-------------------------------------------------------------------------------------------------------------------------------------")
    print(f"cards from page {page}")
    next_page_element = driver.find_element("xpath", "/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[5]/a[2]")
    next_page_element.click()    
print("------------------------------end----------------------------------------------------")

driver.quit()

# %% [markdown]
# ### in this section we are going to access detailed description of each each and return to main page
# step1 here we are using current window handler in driver to save main card
#
# step 2 : we are using card link to and entering into card
#
# step3 : we wanted to switch to new tab
#  we use window handles method inside driver that has id for each tab making it ease for identificatioin process of new tab  using list comprehension and selecting value at 0 index
#  after we use switch_to.window method to switch we also pass new tab as paramater
#
# step 4 : fetch datafrom new tab and close tab
#
# step 5 : go back to main page and repeat the preocess untill specific page

# %%
#driver code to start selenium 
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
chrome_options = Options()
chrome_options.add_experimental_option("detach",True)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),options=chrome_options)
driver.get("https://housing.com/in/buy/chennai/house-chennai?page=2")

# for each page data record
for card in range(1,5):
    #store original url of main page
    main_tab = driver.current_window_handle
    
    # click part of property card takes place
    property_link = driver.find_element("xpath",f"/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[{card}]/div/article/div[1]/div[2]/div[1]/div[1]/div[1]/a")
    property_link.click()

    # switching from main to new tab 
    all_tabs = driver.window_handles
    new_tab = [tab for tab in all_tabs if tab!=main_tab][0]
    driver.switch_to.window(new_tab) 

    # after above code we are inside new page now fetch data 
    print("--------------------------------------------------------------------------------------------------------------------------------------")
    property_title = driver.find_element("xpath","/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/div[2]/div/div[1]/div[1]/div[1]/h1/div[1]/div")
    print(property_title.text)

    property_price = driver.find_element("xpath","/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/div[2]/div/div[2]/div[1]/span")
    print(property_price.text)

    property_area = driver.find_element("xpath","/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[1]/div[1]/div/div")
    print(property_area.text)

    property_avg_price = driver.find_element("xpath","/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[2]/div[1]")
    print(property_avg_price.text)

    property_facing = driver.find_element("xpath","/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[5]/div[1]")
    print(property_facing.text)

    property_furnishing = driver.find_element("xpath","/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[6]/div[1]")
    print(property_furnishing.text)

    property_numberofbedrooms = driver.find_element("xpath","/html/body/div[1]/div[1]/div[3]/div[1]/div[2]/div[1]/section[2]/div/section[2]/table/tbody/tr[3]/td/div")
    print(property_numberofbedrooms.text)

    property_numberofBathrooms = driver.find_element("xpath","/html/body/div[1]/div[1]/div[3]/div[1]/div[2]/div[1]/section[2]/div/section[2]/table/tbody/tr[4]/td/div")
    print(property_numberofbedrooms.text)

    property_numberofBalcony = driver.find_element("xpath","/html/body/div[1]/div[1]/div[3]/div[1]/div[2]/div[1]/section[2]/div/section[2]/table/tbody/tr[6]/td/div")
    print(property_numberofBalcony.text)

    property_score_connectivity = driver.find_element("xpath","/html/body/div[1]/div[1]/div[3]/div[1]/div[2]/div[1]/section[4]/section/div[2]/div/div/div[3]/div[1]/p")
    print(property_score_connectivity.text)

    property_score_neighbourhood = driver.find_element("xpath","/html/body/div[1]/div[1]/div[3]/div[1]/div[2]/div[1]/section[4]/section/div[2]/div/div/div[3]/div[2]/p")
    print(property_score_neighbourhood.text)

    property_score_safety = driver.find_element("xpath","/html/body/div[1]/div[1]/div[3]/div[1]/div[2]/div[1]/section[4]/section/div[2]/div/div/div[3]/div[3]/p")
    print(property_score_safety.text)

    property_score_livability = driver.find_element("xpath","/html/body/div[1]/div[1]/div[3]/div[1]/div[2]/div[1]/section[4]/section/div[2]/div/div/div[3]/div[4]/p")
    print(property_score_livability.text)

    #closing the new tab and going back to old ones 
    driver.close()
    driver.switch_to.window(new_tab)

# %% [markdown]
# made some changes and optimised code

# %%
#driver code to start selenium 
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

chrome_options = Options()
chrome_options.add_experimental_option("detach",True)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),options=chrome_options)
driver.get("https://housing.com/in/buy/chennai/house-chennai?page=3")

def get_text(xpath):
    try:
        return driver.find_element(By.XPATH, xpath).text
    except:
        return "N/A"

def safe_print(label, xpath):
    try:
        print(f"{label}: {get_text(xpath)}")
    except Exception as e:
        print(f"{label}: Error - {e}")

# for each page data record
for card in range(1,5):
    #store original url of main page
    main_tab = driver.current_window_handle
    
    # click part of property card takes place
    property_link = driver.find_element("xpath",f"/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[{card}]/div/article/div[1]/div[2]/div[1]/div[1]/div[1]/a")
    property_link.click()

    # switching from main to new tab 
    all_tabs = driver.window_handles
    new_tab = [tab for tab in all_tabs if tab!=main_tab][0]
    driver.switch_to.window(new_tab) 

    # after above code we are inside new page now fetch data 
    safe_print("Title", "/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/div[2]/div/div[1]/div[1]/div[1]/h1/div[1]/div")
    safe_print("Price", "/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/div[2]/div/div[2]/div[1]/span")
    safe_print("Area", "/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[1]/div[1]/div/div")
    safe_print("Avg Price", "/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[2]/div[1]")
    safe_print("Facing", "/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[4]/div[1]")
    safe_print("Furnishing", "/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[5]/div[1]")
    safe_print("Bedrooms", "/html/body/div[1]/div[1]/div[3]/div[1]/div[2]/div[1]/section[2]/div/section[2]/table/tbody/tr[3]/td/div")
    safe_print("Bathrooms", "/html/body/div[1]/div[1]/div[3]/div[1]/div[2]/div[1]/section[2]/div/section[2]/table/tbody/tr[4]/td/div")
    safe_print("Balcony", "/html/body/div[1]/div[1]/div[3]/div[1]/div[2]/div[1]/section[2]/div/section[2]/table/tbody/tr[6]/td/div")
    safe_print("Connectivity Score", "/html/body/div[1]/div[1]/div[3]/div[1]/div[2]/div[1]/section[4]/section/div[2]/div/div/div[3]/div[1]/p")
    safe_print("Neighbourhood Score", "/html/body/div[1]/div[1]/div[3]/div[1]/div[2]/div[1]/section[4]/section/div[2]/div/div/div[3]/div[2]/p")
    safe_print("Safety Score", "/html/body/div[1]/div[1]/div[3]/div[1]/div[2]/div[1]/section[4]/section/div[2]/div/div/div[3]/div[3]/p")
    safe_print("Livability Score", "/html/body/div[1]/div[1]/div[3]/div[1]/div[2]/div[1]/section[4]/section/div[2]/div/div/div[3]/div[4]/p")
    print("--------------------------------------------------------------------------------------------------------------------------")
    #closing the new tab and going back to old ones 
    driver.close()
    driver.switch_to.window(main_tab)

# %% [markdown]
# there is somme error after furshning optimised code with relative x path

# %%
#driver code to start selenium 
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

chrome_options = Options()
chrome_options.add_experimental_option("detach",True)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),options=chrome_options)
driver.get("https://housing.com/in/buy/chennai/house-chennai?page=3")

def get_text(xpath):
    try:
        return driver.find_element(By.XPATH, xpath).text
    except:
        return "N/A"

def safe_print(label, xpath):
    try:
        print(f"{label}: {get_text(xpath)}")
    except Exception as e:
        print(f"{label}: Error - {e}")

def get_by_label_th(label):
    try:
        xpath = f"//tr[th[contains(text(),'{label}')]]/td/div"
        return driver.find_element(By.XPATH, xpath).text
    except:
        return "N/A"


# for each page data record
for card in range(1,3):
    #store original url of main page
    main_tab = driver.current_window_handle
    
    # click part of property card takes place
    property_link = driver.find_element("xpath",f"/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[{card}]/div/article/div[1]/div[2]/div[1]/div[1]/div[1]/a")
    property_link.click()

    # switching from main to new tab 
    all_tabs = driver.window_handles
    new_tab = [tab for tab in all_tabs if tab!=main_tab][0]
    driver.switch_to.window(new_tab) 

    # after above code we are inside new page now fetch data 
    safe_print("Title", "/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/div[2]/div/div[1]/div[1]/div[1]/h1/div[1]/div")
    safe_print("Price", "/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/div[2]/div/div[2]/div[1]/span")
    safe_print("Area", "/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[1]/div[1]/div/div")
    safe_print("Avg Price", "/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[2]/div[1]")
    safe_print("Facing", "/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[4]/div[1]")
    safe_print("Furnishing", "/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[5]/div[1]")
    print("Bedrooms:", get_by_label_th("Bedrooms"))
    print("Bathrooms:", get_by_label_th("Bathrooms"))
    print("Balcony:", get_by_label_th("Balcony"))
    
    containers = driver.find_elements(By.XPATH, "//div[contains(@class, 'T_featureContainerStyle')]")
    
    for container in containers:
        label = container.find_element(By.TAG_NAME, "span").text    # Get label from <span>
        score = container.find_element(By.TAG_NAME, "p").text       # Get score from <p>
        print(f"{label}: {score}")
    print("--------------------------------------------------------------------------------------------------------------------------")
    #closing the new tab and going back to old ones 
    driver.close()
    driver.switch_to.window(main_tab)
driver.quit()

# %% [markdown]
# ### introduced pandas and converted into csv file

# %%
# Add import for pandas
import pandas as pd

# 🔹 Create an empty list to store each record
data = []

# for each page data record
for card in range(1, 3):
    main_tab = driver.current_window_handle

    property_link = driver.find_element("xpath", f"/html/body/div[1]/div[1]/div[3]/div[2]/div[1]/div[4]/div[{card}]/div/article/div[1]/div[2]/div[1]/div[1]/div[1]/a")
    property_link.click()

    all_tabs = driver.window_handles
    new_tab = [tab for tab in all_tabs if tab != main_tab][0]
    driver.switch_to.window(new_tab)

    # 🔹 Initialize dictionary to store this property's data
    property_data = {}

    # 🔹 Fetch and store data
    property_data["Title"] = get_text("/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/div[2]/div/div[1]/div[1]/div[1]/h1/div[1]/div")
    property_data["Price"] = get_text("/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/div[2]/div/div[2]/div[1]/span")
    property_data["Area"] = get_text("/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[1]/div[1]/div/div")
    property_data["Avg Price"] = get_text("/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[2]/div[1]")
    property_data["Facing"] = get_text("/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[4]/div[1]")
    property_data["Furnishing"] = get_text("/html/body/div[1]/div[1]/div[3]/div[1]/div[1]/div/section/div[5]/div[1]")

    property_data["Bedrooms"] = get_by_label_th("Bedrooms")
    property_data["Bathrooms"] = get_by_label_th("Bathrooms")
    property_data["Balcony"] = get_by_label_th("Balcony")

    # 🔹 Handle score containers
    containers = driver.find_elements(By.XPATH, "//div[contains(@class, 'T_featureContainerStyle')]")
    for container in containers:
        try:
            label = container.find_element(By.TAG_NAME, "span").text
            score = container.find_element(By.TAG_NAME, "p").text
            property_data[label] = score
        except:
            continue

    # 🔹 Append this record to the list
    data.append(property_data)

    driver.close()
    driver.switch_to.window(main_tab)

driver.quit()

# 🔹 Create DataFrame and export to CSV
df = pd.DataFrame(data)
df.to_csv("property_data.csv", index=False)
print("✅ Data saved to property_data.csv")

# %% [markdown]
# ### in this section we are going to utilies search button
#
# step 1 find elemet
#
# step2 use send keys method to send the data to web
#
# step 3 use sendkeys and Keys.return to get web page

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time 
chrome_options = Options()
chrome_options.add_experimental_option("detach",True)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),options=chrome_options)
driver.get("https://housing.com/")
time.sleep(2)
search_element = driver.find_element("xpath",'/html/body/div[1]/div[1]/div[4]/div/div/div[1]/div/div[2]/input')
search_element.send_keys("kodungaiyur, chennai")
time.sleep(2)
search_element.send_keys(Keys.RETURN)

# %% [markdown]
# ### combine all features of above into a single code
# step1 : driver main url of housing.com
#
# step 2 : i will get list of area in form of list
#
# step 3: search for the particular area in housing.com
#
# step4 : scrape data from each card by using switch tabs and closing them
#
# step 5 : once desired number of data is scraped we are going to return to home page and repeat the process
